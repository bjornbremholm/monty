# %%
# Import packages

import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import requests
import os
import re
from bs4 import BeautifulSoup
import time

import json
import tweepy
import webbrowser

# %%
consumer_key = 'wVj7t29E8C5QLB2uB1JcygtXC'
consumer_secret = 'tp6r7cVQBc2hX3qCO9J25xvcHIIYDOQ4zzaIx0398REhQlJVpY'

callback_url = 'oob'
# url = 'https://twitter.com/JeppeKofod'



auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_url)

try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=7Wc0qQAAAAABSrFTAAABe02e7Jk

# %%
user_pin_input = input('What is the pin value? ')
# user_pint_input = 2750298

# %%
auth.get_access_token(user_pin_input)
# Out:
# ('902544912-aeFMPvRnBgXZQzCfUUDuriiCZWKq8kI2ZjxEM4kV',
#  'H14lnpLXCZaGBghUQsy9F0LNE55vBlKZAuFpHcYxdNwLG')

# %%
api = tweepy.API(auth)
me = api.me()
print(me.screen_name)
# Out:
# ChristofferGad

# %%
# my_timeline = api.home_timeline()
my_timeline = api.get_user('JeppeKofod')
user = api.get_user('JeppeKofod')
user_timeline = user.timeline()
# print(my_timeline)
# my_timeline

# %%
status_dict = dict(vars(status))
keys = status_dict.keys()
single_tweet_data = {'user': status.user.screen_name,'author' : status.author.screen_name}
for k in keys:
    try:
        v_type = type(status_dict[k])
    except:
        v_type = None
    if v_type != None:
        if v_type in allowed_types:
            single_tweet_data[k] = status_dict[k]
            columns.add(k)
tweets_data.append(single_tweet_data)

header_cols = list(columns)
header_cols.append('User')
header_cols.append('Author')

# %%
columns = set()
allowed_types = [str, int]
tweets_data = []
my_timeline = user_timeline

for status in my_timeline:
    # print(status.text)
    # print(type(vars(status)))
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {'user': status.user.screen_name,'author' : status.author.screen_name}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)

header_cols = list(columns)
header_cols.append('User')
header_cols.append('Author')

# %%
status.author.screen_name
# Out:
# 'Snapchat'

# %%
df = pd.DataFrame(tweets_data, columns=header_cols)
df
# Out:
#    lang               id_str                   id  \
# 0    en  1426950162287677440  1426950162287677440
# 1    da  1426196109895127052  1426196109895127052
# 2    en  1424748837525204997  1424748837525204997
# 3    en  1424381051955294208  1424381051955294208
# 4    en  1422500335105581056  1422500335105581056
# 5    da  1420820076974985224  1420820076974985224
# 6    en  1420749714924789765  1420749714924789765
# 7    da  1420654160702226433  1420654160702226433
# 8    en  1418543123131666436  1418543123131666436
# 9    da  1418141913857802244  1418141913857802244
# 10   en  1417061229013700614  1417061229013700614
# 11   en  1415975161757536257  1415975161757536257
# 12   en  1415357318863204361  1415357318863204361
# 13   en  1415195530729304064  1415195530729304064
# 14   da  1414916723724234756  1414916723724234756
# 15   de  1414629550546432002  1414629550546432002
# 16   en  1414514826618052609  1414514826618052609
# 17   en  1413196375609774080  1413196375609774080
# 18   da  1413173616947118088  1413173616947118088
# 19   en  1413098224672514054  1413098224672514054
#
#                                                  text quoted_status_id_str  \
# 0   RT @jensstoltenberg: Spoke with #UK PM @BorisJ...                  NaN
# 1   Danskere i Afghanistan bør forlade landet omgå...                  NaN
# 2   🤍❤️🤍 Today marks the 1-year anniversary of the...                  NaN
# 3   Denmark fully backs and joins the internationa...  1424320489917386752
# 4   Deeply shocked by the horrific death of Belaru...                  NaN
# 5   RT @berlingske: »Danmark lader ikke nogen i st...                  NaN
# 6   RT @EUACI_Ukraine: 🙌 EUACI is blessed to work ...                  NaN
# 7   🇫🇴Góða ólavsøku!\n \nJeg ønsker alle færinger ...                  NaN
# 8   Severe rainfall in #Henan province in Central ...                  NaN
# 9   I dag går alle tanker til vores norske broderf...                  NaN
# 10  Denmark shares EU concerns over cyberattacks u...                  NaN
# 11  The devastating loss of life, high number of i...                  NaN
# 12  Lukashenko again targeting human rights defend...                  NaN
# 13  RT @DenmarkinUSA: Great to have 🇩🇰 Foreign Min...                  NaN
# 14  RT @DanishMFA: Opbakning i 🇪🇺 til 🇩🇰 tech-init...                  NaN
# 15  RT @AuswaertigesAmt: @HeikoMaas hat seine nord...                  NaN
# 16  RT @vestager: Excellent discussion on geopolit...                  NaN
# 17  RT @DKAMBinLT: Good-bye Minister @JeppeKofod. ...                  NaN
# 18  RT @DanishMFA: Denne uge besøgte udenrigsminis...                  NaN
# 19  RT @DanishMFA: Today @JeppeKofod announced EUR...                  NaN
#
#     quoted_status_id  retweet_count                           source_url  \
# 0                NaN            482   http://twitter.com/download/iphone
# 1                NaN             13   http://twitter.com/download/iphone
# 2                NaN             34   http://twitter.com/download/iphone
# 3       1.424320e+18              8   http://twitter.com/download/iphone
# 4                NaN             15   http://twitter.com/download/iphone
# 5                NaN              5   http://twitter.com/download/iphone
# 6                NaN              4   http://twitter.com/download/iphone
# 7                NaN             11   http://twitter.com/download/iphone
# 8                NaN              0   http://twitter.com/download/iphone
# 9                NaN             11   http://twitter.com/download/iphone
# 10               NaN             22   http://twitter.com/download/iphone
# 11               NaN             37  http://twitter.com/#!/download/ipad
# 12               NaN             13   http://twitter.com/download/iphone
# 13               NaN              8   http://twitter.com/download/iphone
# 14               NaN              6   http://twitter.com/download/iphone
# 15               NaN              4  http://twitter.com/#!/download/ipad
# 16               NaN             25   http://twitter.com/download/iphone
# 17               NaN              7   http://twitter.com/download/iphone
# 18               NaN             12   http://twitter.com/download/iphone
# 19               NaN             13   http://twitter.com/download/iphone
#
#                 source  favorite_count  User  Author
# 0   Twitter for iPhone               0   NaN     NaN
# 1   Twitter for iPhone              67   NaN     NaN
# 2   Twitter for iPhone             284   NaN     NaN
# 3   Twitter for iPhone              27   NaN     NaN
# 4   Twitter for iPhone              83   NaN     NaN
# 5   Twitter for iPhone               0   NaN     NaN
# 6   Twitter for iPhone               0   NaN     NaN
# 7   Twitter for iPhone              82   NaN     NaN
# 8   Twitter for iPhone              13   NaN     NaN
# 9   Twitter for iPhone             130   NaN     NaN
# 10  Twitter for iPhone              55   NaN     NaN
# 11    Twitter for iPad             217   NaN     NaN
# 12  Twitter for iPhone              40   NaN     NaN
# 13  Twitter for iPhone               0   NaN     NaN
# 14  Twitter for iPhone               0   NaN     NaN
# 15    Twitter for iPad               0   NaN     NaN
# 16  Twitter for iPhone               0   NaN     NaN
# 17  Twitter for iPhone               0   NaN     NaN
# 18  Twitter for iPhone               0   NaN     NaN
# 19  Twitter for iPhone               0   NaN     NaN
