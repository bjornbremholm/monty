# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
import requests
import re
from bs4 import BeautifulSoup

# %%
df_burger = pd.read_csv('fastfood_export.csv')
# df_burger = df_burger[2:]
df_burger = df_burger.rename(columns = {'Unnamed: 0':'Order time','normalized_turnover':'Delivery', 'normalized_turnover.1':'In Store','normalized_turnover.2':'Wolt'})
df_burger
# Out:
#                 Order time  Delivery normalized_turnover.1  \
# 0            delivery_type  delivery              in store
# 1               order_time       NaN                   NaN
# 2      2020-01-01 10:00:00       0.0    -1.517361813049761
# 3      2020-01-01 11:00:00       0.0    -1.278680741365316
# 4      2020-01-01 12:00:00       0.0     5.226030063531204
# ...                    ...       ...                   ...
# 14065  2021-08-09 09:00:00       0.0                   0.0
# 14066  2021-08-09 10:00:00       0.0                   0.0
# 14067  2021-08-09 11:00:00       0.0   -1.0681607284869536
# 14068  2021-08-09 12:00:00       0.0   -1.4102497132626455
# 14069  2021-08-09 13:00:00       0.0   -0.7010487112796204
#
#       normalized_turnover.2
# 0                      wolt
# 1                       NaN
# 2                       0.0
# 3                       0.0
# 4                       0.0
# ...                     ...
# 14065                   0.0
# ...
