# %%
import numpy as np 
import pandas as pd
import graph_tools
from topsbm import TopSBM

import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-8e304711ec54> in <module>
#       2 import pandas as pd
#       3 import graph_tools
# ----> 4 from topsbm import TopSBM
#       5
#       6 import time
#
# /opt/anaconda3/lib/python3.8/site-packages/topsbm/__init__.py in <module>
#       9
#      10 if not __IN_SETUP__:
# ---> 11     from .transformer import TopSBM
#      12     __all__ = ['TopSBM']
#      13
#
# /opt/anaconda3/lib/python3.8/site-packages/topsbm/transformer.py in <module>
#      19
#      20 import numpy as np
# ---> 21 import graph_tool
#      22 from graph_tool import Graph
#      23 from graph_tool.inference import minimize_nested_blockmodel_dl
#
# ModuleNotFoundError: No module named 'graph_tool'

# %%
df_Name1 = pd.read_csv('Name_id_list.csv')
df_Name2 = pd.read_csv('Name_id_list1.csv')
df_Name3 = pd.read_csv('Name_id_list2.csv')
df_Name4 = pd.read_csv('Name_id_list3.csv')
df_Name5 = pd.read_csv('Name_id_list4.csv')
df_Name6 = pd.read_csv('Name_id_list5.csv')

# %%
df_Name_id_Final1 = pd.concat([df_Name1,df_Name2,df_Name3,df_Name4,df_Name5,df_Name6,],ignore_index=True)

# %%
df_Name_id_Final1
# Out:
#      Unnamed: 0                  Name                               Party  \
# 0             0             Ida Auken               Socialdemokratiet (S)
# 1             1         Trine Bramsen               Socialdemokratiet (S)
# 2             2     Bjørn Brandenborg               Socialdemokratiet (S)
# 3             3           Jeppe Bruus               Socialdemokratiet (S)
# 4             4        Morten Bødskov               Socialdemokratiet (S)
# ..          ...                   ...                                 ...
# 158          18            Uffe Elbæk  Uden for folketingsgrupperne (UFG)
# 159          19  Lars Løkke Rasmussen  Uden for folketingsgrupperne (UFG)
# 160          20     Sikandar Siddique  Uden for folketingsgrupperne (UFG)
# 161          21        Susanne Zimmer  Uden for folketingsgrupperne (UFG)
# 162          22          Orla Østerby  Uden for folketingsgrupperne (UFG)
#
#     Color                     MP        Twitter_id  Følgere  y  Tweet Count
# ...
