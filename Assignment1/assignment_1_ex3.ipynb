# %% [markdown]
# # Mandatory Assignment 1
#
# This is the second of three mandatory assignments which must be completed during the course. Note that you only need to pass 2 out of 3 assignments to be eligible for the exam.
#
# First some practical pieces of information:
#
# * When is the assignment due?: **23:59, Friday, August 6, 2020.**
# * Should i work with my group?: **Yes**. In particular, you should **only hand in 1 assignment per group and in a comment on Absalon write your group number and all group members**.
#
# The assignment consists of problems from some of the exercise sets that you have solved so far. Some exercises are modified a little to better suit the structure of the assignment.
#
# **Note**: It is important that you submit your edited version of THIS [notebook](https://fileinfo.com/extension/ipynb#:~:text=An%20IPYNB%20file%20is%20a,Python%20language%20and%20their%20data.) (the one you have downloaded from Absalon) as a .ipynb file and nothing else. Do not copy your answers into another notebook that you have made.

# %% [markdown]
# ## Problems from Exercise Set 2:
#
# We continue with the exercise that analyzes NOAA data. This time we are going to **read the weather data from a csv file** located in this assignment directory instead of trying to request the website. The file is called `'weather_data_1870-1875.csv'` and consists of weather data for the period 1870-1875. Specifically, the csv file contains a dataframe which has been constructed by concatenating the _non-processed_ data from 1870-1875.

# %% [markdown]
# > **Ex. 2.3.4:** The code below runs through some of the steps we completed in exercise 2.3.4 in Module 2. As we are not going to request the website but load the data from a csv file, your task is to **rewrite parts of the function**. In particular, you need to do the following:
# >1. Rename the function to `process_weather` instead of `load_weather`.
# >2. The function should now  take a `dataframe` as input.
# >3. Consider whether `df_weather.iloc[:, :4]` is necessary for the weather data loaded from  the csv file. The documentation string should also be rewritten appropriately.
# >4. The function contains a sorting step. **Change it so that it first sorts by _station_, then by _datetime_. The sorting should be ascending for _station_ and descending for _datetime_.**
# >5. After having rewritten the function, load the weather data from `'weather_data_1870-1875.csv'` into a pandas dataframe, apply the `process_weather` function to this dataframe, and store the result in the variable `df_weather_period`.
#
# ```python
# import pandas as pd
#
# def load_weather(year):
#
#     '''
#     This functions loads the data for selected year and then structures and cleans it.
#     - Structuring includes removing unused columns, renaming and selecting only observations
#     of maximum temperature.
#     - Cleaning includes inserting missing decimal, sorting and resetting index.
#     '''
#     url = f"ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/{year}.csv.gz"
#
#     # loads the data
#     df_weather = pd.read_csv(url, header=None)\
#                     .iloc[:,:4]
#
#     # structure and clean data using methods chaining
#     # note that the original columns now are strings when loading the csv file
#     # and not integers as when downloading the data
#     df_out = \
#         df_weather\
#             .rename(columns={'0': 'station', '1': 'datetime', '2': 'obs_type', '3': 'obs_value'})\
#             .query("obs_type == 'TMAX'")\
#             .assign(obs_value=lambda df: df['obs_value']/10)\
#             .sort_values(by=['station', 'datetime'])\
#             .reset_index(drop=True)\
#             .copy()
#
#     # area process
#     df_out['area'] = df_out['station'].str[0:2]
#
#     # datetime process
#     df_out['datetime_dt'] = pd.to_datetime(df_out['datetime'], format = '%Y%m%d')
#     df_out['month'] = df_out['datetime_dt'].dt.month
#     df_out['year'] = df_out['datetime_dt'].dt.year
#
#     return df_out
# ```

# %%
import pandas as pd

def process_weather(df):
    
    '''
    Input: Dataframe with 4 columns: station id, datetime, obs_type, obs_value
    
    Output: Processed dataframe with 4 additional columns: area, datetime_dt, month, year

    Process includes:
    - Renameing columns
    - Selecting only oberservations with maximum temerature
    - Compiling additional columns
    - Sorting: 1. station 2. datetime
    - Resetting index
    '''
    
    # Process dataframe using methods chaining
    df_out = \
        df\
            .rename(columns={'0': 'station', '1': 'datetime', '2': 'obs_type', '3': 'obs_value'})\
            .query("obs_type == 'TMAX'")\
            .assign(\
                obs_value=lambda df: df['obs_value']/10,\
                area = lambda df: df['station'].str.extract('([a-zA-Z]+)').astype('category'),\
                datetime_dt = lambda df: pd.to_datetime(df['datetime'], format = '%Y%m%d'),\
                month = lambda df: df['datetime_dt'].dt.month.map('{:02}'.format),\
                year = lambda df: df['datetime_dt'].dt.year)\
            .sort_values(by=['station', 'datetime'],ascending = (True,False))\
            .reset_index(drop=True)\
            .copy() 

    
    return df_out

data = pd.read_csv('weather_data_1870-1875.csv')
df_weather_period = process_weather(data)
print(df_weather_period.dtypes)
df_weather_period
# Out:
# station                object
# datetime                int64
# obs_type               object
# obs_value             float64
# area                   object
# datetime_dt    datetime64[ns]
# month                  object
# year                    int64
# dtype: object
#             station  datetime obs_type  obs_value area datetime_dt month  year
# 0       ASN00048013  18751117     TMAX       38.3  ASN  1875-11-17    11  1875
# 1       ASN00048013  18751116     TMAX       33.8  ASN  1875-11-16    11  1875
# 2       ASN00048013  18751115     TMAX       32.8  ASN  1875-11-15    11  1875
# 3       ASN00048013  18751114     TMAX       35.6  ASN  1875-11-14    11  1875
# 4       ASN00048013  18751113     TMAX       29.7  ASN  1875-11-13    11  1875
# ...             ...       ...      ...        ...  ...         ...   ...   ...
# 132312  USW00094728  18700105     TMAX        1.1  USW  1870-01-05    01  1870
# 132313  USW00094728  18700104     TMAX        1.7  USW  1870-01-04    01  1870
# 132314  USW00094728  18700103     TMAX        5.0  USW  1870-01-03    01  1870
# 132315  USW00094728  18700102     TMAX       12.2  USW  1870-01-02    01  1870
# 132316  USW00094728  18700101     TMAX        6.1  USW  1870-01-01    01  1870
#
# [132317 rows x 8 columns]

# %% [markdown]
# > **Ex. 2.NEW (Not seen in module 2):** Try to plot the observations value of `df_weather_period` by running `df_weather_period.obs_value.plot()`. Something seems off, right? Now try to inspect the problematic subset of the dataframe by running `df_weather_period[df_weather_period.obs_value < -50]`. What can these three observations be characterized as? Drop ALL observations from the associated station from `df_weather_period`, reset the index and drop the column with the old index. Store the dataframe back into the variable `df_weather_period`.

# %%
# Drop the observations below -50 - these contain measurement errors (or mislabeled)
df_weather_period = df_weather_period[df_weather_period['obs_value'] >= -50]

# Reset index
df_weather_period = df_weather_period.reset_index(drop = True)

df_weather_period
# Out:
#             station  datetime obs_type  obs_value area datetime_dt month  \
# 0       ASN00048013  18751117     TMAX       38.3  ASN  1875-11-17    11
# 1       ASN00048013  18751116     TMAX       33.8  ASN  1875-11-16    11
# 2       ASN00048013  18751115     TMAX       32.8  ASN  1875-11-15    11
# 3       ASN00048013  18751114     TMAX       35.6  ASN  1875-11-14    11
# 4       ASN00048013  18751113     TMAX       29.7  ASN  1875-11-13    11
# ...             ...       ...      ...        ...  ...         ...   ...
# 132309  USW00094728  18700105     TMAX        1.1  USW  1870-01-05    01
# 132310  USW00094728  18700104     TMAX        1.7  USW  1870-01-04    01
# 132311  USW00094728  18700103     TMAX        5.0  USW  1870-01-03    01
# 132312  USW00094728  18700102     TMAX       12.2  USW  1870-01-02    01
# 132313  USW00094728  18700101     TMAX        6.1  USW  1870-01-01    01
#
#         year  tmax_mean  tmax_median
# 0       1875  32.241176         31.9
# 1       1875  32.241176         31.9
# 2       1875  32.241176         31.9
# 3       1875  32.241176         31.9
# 4       1875  32.241176         31.9
# ...      ...        ...          ...
# 132309  1870   6.564516          6.7
# 132310  1870   6.564516          6.7
# 132311  1870   6.564516          6.7
# 132312  1870   6.564516          6.7
# 132313  1870   6.564516          6.7
#
# [132314 rows x 10 columns]

# %% [markdown]
# > **Ex. 2.3.2:**
# Continuing with the `df_weather_period` from last exercise, do the following:
# > 1. Convert the `area` column to a categorical variable.
# > 2. Transform the `obs_value` column from a continuous to a categorical variable by partitioning it into `3` intervals. The first interval should contain observations with values of `obs_value` up to the 10% quantile. The second interval should contain observations with values of `obs_value` up to the 90% quantile. The third interval should contain the rest of the observations. Call this new column for `obs_value_cat`.  This can be done using the `pd.qcut()` method.
# > 3. Make another column with  `obs_value` as a categorical variable but this time label the 3 intervals as `["cold", "medium", "hot"]`. This can be done by specifying the `labels` parameter in the `pd.qcut()` method of pandas. Call this new column for `obs_value_cat_labeled`.

# %%
# Making area a categorical variable
df_weather_period['area'] = df_weather_period['area'].astype('category')

# Creating observational categories
df_weather_period['obs_value_cat'] = pd.qcut(df_weather_period['obs_value'],q=[0,0.1,0.9,1])

# Creating observational categories labels
df_weather_period['obs_value_cat_labeled'] = pd.qcut(df_weather_period['obs_value'],q=[0,0.1,0.9,1], labels = ['cold','medium','hot'])

# Printing types
print(df_weather_period.dtypes)

# Printing dataframe
df_weather_period
# Out:
# station                          object
# datetime                          int64
# obs_type                         object
# obs_value                       float64
# area                           category
# datetime_dt              datetime64[ns]
# month                            object
# year                              int64
# tmax_mean                       float64
# tmax_median                     float64
# obs_value_cat                  category
# obs_value_cat_labeled          category
# dtype: object
#             station  datetime obs_type  obs_value area datetime_dt month  \
# 0       ASN00048013  18751117     TMAX       38.3  ASN  1875-11-17    11
# 1       ASN00048013  18751116     TMAX       33.8  ASN  1875-11-16    11
# 2       ASN00048013  18751115     TMAX       32.8  ASN  1875-11-15    11
# 3       ASN00048013  18751114     TMAX       35.6  ASN  1875-11-14    11
# 4       ASN00048013  18751113     TMAX       29.7  ASN  1875-11-13    11
# ...             ...       ...      ...        ...  ...         ...   ...
# 132309  USW00094728  18700105     TMAX        1.1  USW  1870-01-05    01
# 132310  USW00094728  18700104     TMAX        1.7  USW  1870-01-04    01
# 132311  USW00094728  18700103     TMAX        5.0  USW  1870-01-03    01
# 132312  USW00094728  18700102     TMAX       12.2  USW  1870-01-02    01
# 132313  USW00094728  18700101     TMAX        6.1  USW  1870-01-01    01
#
#         year  tmax_mean  tmax_median obs_value_cat obs_value_cat_labeled
# 0       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 1       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 2       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 3       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 4       1875  32.241176         31.9  (28.3, 47.8]                   hot
# ...      ...        ...          ...           ...                   ...
# 132309  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132310  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132311  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132312  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132313  1870   6.564516          6.7  (-1.1, 28.3]                medium
#
# [132314 rows x 12 columns]

# %% [markdown]
# ## Problems from Exercise Set 3:

# %% [markdown]
# > **Ex. 3.3.1:** Compute the mean and median maximum daily temperature for each month-year-station pair on the dataframe `df_weather_period` from last exercise by using the _split-apply-combine_ procedure. Store the results in new columns `tmax_mean` and `tmax_median`.

# %%
# Choosing the variables on which to split the dataset
split_vars = ['month','year','station']
# chossing the temperature as variable on which to compute descriptive statistics
apply_vars = ['obs_value']
# choosing which statistics to compute
apply_fcts = ['median', 'mean']

# appending two new columns containing the mean and median for each month-year-station pair
df_weather_period['tmax_mean'] = df_weather_period.groupby(split_vars)[apply_vars].transform('mean')
df_weather_period['tmax_median'] = df_weather_period.groupby(split_vars)[apply_vars].transform('median')
print(df_weather_period)
# Out:
#             station  datetime obs_type  obs_value area datetime_dt month  \
# 0       ASN00048013  18751117     TMAX       38.3  ASN  1875-11-17    11
# 1       ASN00048013  18751116     TMAX       33.8  ASN  1875-11-16    11
# 2       ASN00048013  18751115     TMAX       32.8  ASN  1875-11-15    11
# 3       ASN00048013  18751114     TMAX       35.6  ASN  1875-11-14    11
# 4       ASN00048013  18751113     TMAX       29.7  ASN  1875-11-13    11
# ...             ...       ...      ...        ...  ...         ...   ...
# 132309  USW00094728  18700105     TMAX        1.1  USW  1870-01-05    01
# 132310  USW00094728  18700104     TMAX        1.7  USW  1870-01-04    01
# 132311  USW00094728  18700103     TMAX        5.0  USW  1870-01-03    01
# 132312  USW00094728  18700102     TMAX       12.2  USW  1870-01-02    01
# 132313  USW00094728  18700101     TMAX        6.1  USW  1870-01-01    01
#
#         year  tmax_mean  tmax_median obs_value_cat obs_value_cat_labeled
# 0       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 1       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 2       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 3       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 4       1875  32.241176         31.9  (28.3, 47.8]                   hot
# ...      ...        ...          ...           ...                   ...
# 132309  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132310  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132311  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132312  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132313  1870   6.564516          6.7  (-1.1, 28.3]                medium
#
# [132314 rows x 12 columns]

# %% [markdown]
# > **Ex. 3.3.2:** Plot the monthly max,min, mean, first and third quartiles for maximum temperature for the station with ID _'CA006110549'_ from `df_weather_period`.
#
# > *Hint*: the method `describe` computes all these measures. Try to make your plot look like the one below.
# <img src="station_data_plot.png">

# %%
# plotting descriptive statistics for the given station
# choosing the given station
CA_station = df_weather_period[df_weather_period['station'] == 'CA006110549']

# Choosing the variables on which to split the dataset
split_vars = ['month']
# chossing the temperature as variable on which to compute descriptive statistics
apply_vars = ['obs_value']
# choosing which statistics to show
stats = ['mean', 'min', 'max', '25%', '75%']
# CA_station.groupby(split_vars)[apply_vars].describe().obs_value[stats].plot()
CA_plotdata = CA_station.groupby(split_vars)[apply_vars].describe().obs_value[stats]

# %%
import numpy as np
import matplotlib.pyplot as plt

f,ax = plt.subplots()

mean = ax.plot(CA_plotdata['mean'], color = 'red', label='mean') # Choose lineplot
lowerband = ax.plot(CA_plotdata['25%'], dashes=[6, 2], color = 'blue', linewidth = 1, label = 'first quartile') 
upperband = ax.plot(CA_plotdata['75%'], dashes=[6, 2], color = 'blue', linewidth = 1, label = 'third quartile') 
mindots = ax.plot(CA_plotdata['min'], color='blue', marker='o', linestyle = 'None', markersize=3, label = 'min') 
maxdots = ax.plot(CA_plotdata['max'], color='blue', marker='o', linestyle = 'None', markersize=3, label = 'max') 

ax.set_title('Average and band of temperature at CA006110549') # Choose title for plot
ax.title.set_fontsize(14) # Choose title font size

ax.set_xlabel('Month') # Choose title x-axis
ax.xaxis.label.set_fontsize(12) # Choose font size for x-axis title

ax.set_ylabel('°, Celsius') # Choose title y-axis
ax.yaxis.label.set_fontsize(12) # Choose font size for y-axis title

ax.legend(loc = 'upper left', bbox_to_anchor=(1.05, 1))
    
# for item in ax.get_yticklabels()+ax.get_xticklabels():
#     item.set_fontsize(12) # Choose size of ticks
# plt.show()

# %% [markdown]
# > **Ex. 3.3.3:** Use the station location data, which is located in this directory, to merge station locations onto `df_weather_period`. The file with station location data is called  `ghcnd-stations.txt`.  Store the result in the variable `final_data`.
#
# > _Hint:_ The location data have the folllowing format,
#
# ```
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------
# ```
#
# > *Hint*: The station information has fixed width format - does there exist a pandas reader for that?

# %%
# YOUR CODE HERE
url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt'
data = pd.read_fwf(url,header=None)

# %%
df_location = data.rename(columns={0: 'station', 1: 'latitude', 2: 'longtitude', 3: 'elevation', 4: 'state', 5: 'name', 6: 'gsn_flag', 7: 'hscn/crn_flag'})
df_location
# Out:
#             station  latitude  longtitude  elevation                  state  \
# 0       ACW00011604   17.1167    -61.7833       10.1  ST JOHNS COOLIDGE FLD
# 1       ACW00011647   17.1333    -61.7833       19.2               ST JOHNS
# 2       AE000041196   25.3330     55.5170       34.0    SHARJAH INTER. AIRP
# 3       AEM00041194   25.2550     55.3640       10.4             DUBAI INTL
# 4       AEM00041217   24.4330     54.6510       26.8         ABU DHABI INTL
# ...             ...       ...         ...        ...                    ...
# 118487  ZI000067969   21.0500     29.3670      861.0         WEST NICHOLSON
# 118488  ZI000067975   20.0670     30.8670     1095.0               MASVINGO
# 118489  ZI000067977   21.0170     31.5830      430.0          BUFFALO RANGE
# 118490  ZI000067983   20.2000     32.6160     1132.0               CHIPINGE
# 118491  ZI000067991   22.2170     30.0000      457.0             BEITBRIDGE
#
#        name gsn_flag  hscn/crn_flag
# 0       NaN      NaN            NaN
# 1       NaN      NaN            NaN
# 2       NaN      GSN        41196.0
# 3       NaN      NaN        41194.0
# 4       NaN      NaN        41217.0
# ...     ...      ...            ...
# 118487  NaN      NaN        67969.0
# 118488  NaN      NaN        67975.0
# 118489  NaN      NaN        67977.0
# 118490  NaN      GSN        67983.0
# 118491  NaN      NaN        67991.0
#
# [118492 rows x 8 columns]

# %%
final_data = pd.merge(df_weather_period,df_location,on='station')
final_data
# Out:
#             station  datetime obs_type  obs_value area datetime_dt month  \
# 0       ASN00048013  18751117     TMAX       38.3  ASN  1875-11-17    11
# 1       ASN00048013  18751116     TMAX       33.8  ASN  1875-11-16    11
# 2       ASN00048013  18751115     TMAX       32.8  ASN  1875-11-15    11
# 3       ASN00048013  18751114     TMAX       35.6  ASN  1875-11-14    11
# 4       ASN00048013  18751113     TMAX       29.7  ASN  1875-11-13    11
# ...             ...       ...      ...        ...  ...         ...   ...
# 132309  USW00094728  18700105     TMAX        1.1  USW  1870-01-05    01
# 132310  USW00094728  18700104     TMAX        1.7  USW  1870-01-04    01
# 132311  USW00094728  18700103     TMAX        5.0  USW  1870-01-03    01
# 132312  USW00094728  18700102     TMAX       12.2  USW  1870-01-02    01
# 132313  USW00094728  18700101     TMAX        6.1  USW  1870-01-01    01
#
#         year  tmax_mean  tmax_median obs_value_cat obs_value_cat_labeled  \
# 0       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 1       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 2       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 3       1875  32.241176         31.9  (28.3, 47.8]                   hot
# 4       1875  32.241176         31.9  (28.3, 47.8]                   hot
# ...      ...        ...          ...           ...                   ...
# 132309  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132310  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132311  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132312  1870   6.564516          6.7  (-1.1, 28.3]                medium
# 132313  1870   6.564516          6.7  (-1.1, 28.3]                medium
#
#         latitude  longtitude  elevation                  state name gsn_flag  \
# 0        30.0917    145.9358      106.0     BOURKE POST OFFICE  NaN      NaN
# 1        30.0917    145.9358      106.0     BOURKE POST OFFICE  NaN      NaN
# 2        30.0917    145.9358      106.0     BOURKE POST OFFICE  NaN      NaN
# 3        30.0917    145.9358      106.0     BOURKE POST OFFICE  NaN      NaN
# 4        30.0917    145.9358      106.0     BOURKE POST OFFICE  NaN      NaN
# ...          ...         ...        ...                    ...  ...      ...
# 132309   40.7789    -73.9692       39.6  NEW YORK CNTRL PK TWR  NaN      NaN
# 132310   40.7789    -73.9692       39.6  NEW YORK CNTRL PK TWR  NaN      NaN
# 132311   40.7789    -73.9692       39.6  NEW YORK CNTRL PK TWR  NaN      NaN
# 132312   40.7789    -73.9692       39.6  NEW YORK CNTRL PK TWR  NaN      NaN
# 132313   40.7789    -73.9692       39.6  NEW YORK CNTRL PK TWR  NaN      NaN
#
#         hscn/crn_flag
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 132309        72506.0
# 132310        72506.0
# 132311        72506.0
# 132312        72506.0
# 132313        72506.0
#
# [132314 rows x 19 columns]

# %% [markdown]
# ## Problems from Exercise Set 4:
#
# > **Ex. 4.3.5:** This exercise consists of a set of small subelements:
# >
# > 0. Show the first five rows of the titanic dataset. What information is in the dataset?
# > 1. Use a barplot to show the probability of survival for men and women within each passenger class.
# > 2. Can you make a boxplot showing the same information (why/why not?).
# > 3. Show a boxplot for the fare-prices within each passenger class.
# > 4. Combine the two of the figures you created above into a two-panel figure and save it on your computer.

# %%
# YOUR CODE HERE

# %% [markdown]
# > **Ex. 4.3.6:** Using the iris flower dataset, draw a scatterplot of sepal length and petal length. Include a second order polynomial fitted to the data. Add a title to the plot and rename the axis labels.
# >
# > _Write 3 sentences:_ Is this a meaningful way to display the data? What could we do differently?
# >
# > For a better understanding of the dataset this image might be useful:
# > <img src="iris_pic.png" alt="Drawing" style="width: 200px;"/>
# >
# > _Hint:_ Use the `.regplot` method from seaborn.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# > **Ex. 4.3.7:** Use [pairplot with hue](https://seaborn.pydata.org/generated/seaborn.pairplot.html) to create a figure that clearly shows how the different species vary across measurements in the iris dataset. Change the color palette and remove the shading from the density plots. _Bonus:_ Try to explain how the `diag_kws` argument works (_hint:_ [read here](https://stackoverflow.com/questions/1769403/understanding-kwargs-in-python))

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Problems from Exercise Set 6
#
# > **Ex. 6.1.2.:** Use the `request` module to collect the first page of job postings and unpack the relevant `json` data into a `pandas` DataFrame.

# %%
# YOUR CODE HERE
import requests
from bs4 import BeautifulSoup
import re
import selenium
import time
import pandas as pd

import json
import urllib.request

#import io

#from pandas.io.json import json_normalize

# %%
url

# %%
url = 'https://job.jobnet.dk/CV/FindWork/Search?SearchString=polit&Offset=0&SortValue=BestMatch'

page = requests.get(url)
# print(page.text)
df = pd.DataFrame(page.json()['JobPositionPostings'])
# df = pd.DataFrame(df)
df
#print(df)
# Out:
#     AutomatchType  Abroad  Weight  \
# 0               0   False  0.9333
# 1               0   False  0.9170
# 2               0   False  0.9170
# 3               0   False  0.9170
# 4               0   False  0.9170
# 5               0   False  0.9170
# 6               0   False  0.9170
# 7               0   False  0.9170
# 8               0   False  0.9170
# 9               0   False  0.9170
# 10              0   False  0.9170
# 11              0   False  0.9170
# 12              0   False  0.9170
# 13              0   False  0.9170
# 14              0   False  0.9170
# 15              0   False  0.9170
# 16              0   False  0.9170
# 17              0   False  0.9170
# 18              0   False  0.9170
# 19              0   False  0.9170
#
#                                                 Title  \
# 0    Udenrigsministeriet søger to økonomispecialister
# 1   Studentermedhjælpere til Folketingets Økonomis...
# 2                    Studentermedhjælper – FM-enheden
# 3   Datastærk og struktureret studentermedhjælp ti...
# 4        Studentermedhjælper til Etnisk konsulentteam
# 5   Souschef hos Landsbyggefonden i København (HUR...
# 6           Controller til Banedanmark, Driftsøkonomi
# 7   DA søger økonomer til analyser af arbejdsmarkedet
# 8   Projektleder til Københavns Kommunes program f...
# 9   Trafikstyrelsen søger chef for Ledelsessekreta...
# 10                 Konsulent til Analyse og Projekter
# 11     Studentermedhjælpere til Kontor for Konjunktur
# 12  Skatteministeriet søger en student til policy-...
# 13  Generalist til havmiljøteam i Miljøministeriet...
# 14  Nyuddannet talstærk akademiker til Finansminis...
# 15  Studentermedhjælper til Forskningsenheden ved ...
# 16  Ambitiøs medarbejder til Finansministeriets ar...
# 17  Dygtig studentermedhjælper med stor interesse ...
# 18  Skarp data generalist med sans for forretning ...
# 19  Konsulent til ambitiøs analyse- og strategienh...
#
#                                           JobHeadline  \
# 0    Udenrigsministeriet søger to økonomispecialister
# 1   Studentermedhjælpere til Folketingets Økonomis...
# 2                    Studentermedhjælper – FM-enheden
# 3   Datastærk og struktureret studentermedhjælp ti...
# 4        Studentermedhjælper til Etnisk konsulentteam
# 5   Souschef hos Landsbyggefonden i København (HUR...
# 6           Controller til Banedanmark, Driftsøkonomi
# 7   DA søger økonomer til analyser af arbejdsmarkedet
# 8   Projektleder til Københavns Kommunes program f...
# 9   Trafikstyrelsen søger chef for Ledelsessekreta...
# 10                 Konsulent til Analyse og Projekter
# 11     Studentermedhjælpere til Kontor for Konjunktur
# 12  Skatteministeriet søger en student til policy-...
# 13  Generalist til havmiljøteam i Miljøministeriet...
# 14  Nyuddannet talstærk akademiker til Finansminis...
# 15  Studentermedhjælper til Forskningsenheden ved ...
# 16  Ambitiøs medarbejder til Finansministeriets ar...
# 17  Dygtig studentermedhjælper med stor interesse ...
# 18  Skarp data generalist med sans for forretning ...
# 19  Konsulent til ambitiøs analyse- og strategienh...
#
#                                          Presentation  \
# 0   <b>...</b>og hands-on erfaring med regnskabsop...
# 1    ... og upartisk måde.     Din profil       \t...
# 2    ...        \t    Er  i gang med en relevant ø...
# 3   <b>...</b>gang med en relevant datafaglig elle...
# 4    ...  ad hoc-opgaver       Om dig    Du har en...
# 5   <b>...</b>du med en relevant økonomisk baggrun...
# 6   <b>...</b>   <strong>Dygtig akademiker med mod...
# 7    ... os, at du:           \t er en faglig stær...
# 8    ...       \t du har en økonomifaglig baggrund...
# 9    ... bolde i luften.  \t Du har en relevant sa...
# 10   ... forskelligartede interesser.  \t Har en l...
# 11   ... i Finansministeriet.    Om dig  Du er i g...
# 12  <b>...</b>der skal leveres med kort aftræk.<br...
# 13  <b>...</b>med stærke faglige kompetencer. Du k...
# 14   ...    Om dig  Du er nyuddannet med gode resu...
# 15   ... kvalifikationer       \t Studerende inden...
# 16   ...       \t Er en faglig stærk profil inden ...
# 17  <b>...</b>makroøkonomiske forhold.<br><br>  Vi...
# 18   ... udvikle processer og procedurer  \t en ka...
# 19   ... skriftligt og mundtligt.  Har opnået gode...
#
#                                         HiringOrgName  \
# 0                                 Udenrigsministeriet
# 1                         Folketingets administration
# 2                                 Bispebjerg Hospital
# 3        Skatteforvaltningen, KBH, Hannemanns Allé 25
# 4                                  Københavns Kommune
# 5                                          MOMENT A/S
# 6               Banedanmark, Carsten Niebuhrs Gade 43
# 7                          DANSK ARBEJDSGIVERFORENING
# 8                                  Københavns Kommune
# 9                                     Trafikstyrelsen
# 10                             DANMARKS RADIO DR-Byen
# 11                   Finansministeriets Departementet
# 12                                  Skatteministeriet
# 13                                   Miljøministeriet
# 14                                   Økonomistyrelsen
# 15  Børne- og Ungdomspsykiatrisk Center - Afdeling...
# 16                   Finansministeriets Departementet
# 17                   Finansministeriets Departementet
# 18                                   Økonomistyrelsen
# 19                              Frederiksberg Kommune
#
#                WorkPlaceAddress WorkPlacePostalCode  WorkPlaceCity  ...  \
# 0              Asiatisk Plads 2                1402    København K  ...
# 1         Christiansborg Slot 1                1218    København K  ...
# 2           Bispebjerg Bakke 23                2400   København NV  ...
# 3            Hannemanns Allé 25                2300    København S  ...
# 4               Borups Allé 177                2400   København NV  ...
# 5                                              1554    København V  ...
# 6      Carsten Nieburhs Gade 43                1577    København V  ...
# 7           Vester Voldgade 113                1552    København V  ...
# 8               Borups Allé 177                2400   København NV  ...
# 9      Carsten Niebuhrs Gade 43                1577    København V  ...
# 10          Emil Holms Kanal 20                2300    København S  ...
# 11  Christiansborg Slotsplads 1                1218    København K  ...
# 12     Nicolai Eigtveds Gade 28                1402    København K  ...
# 13            Slotsholmsgade 12                1216    København K  ...
# 14                 Landgreven 4                1301    København K  ...
# 15     Gentofte Hospitalsvej 3A                2900       Hellerup  ...
# 16  Christiansborg Slotsplads 1                1218    København K  ...
# 17  Christiansborg Slotsplads 1                1218    København K  ...
# 18                 Landgreven 4                1301    København K  ...
# 19                     Rådhuset                2000  Frederiksberg  ...
#
#     HiringOrgCVR  UserLoggedIn  AnonymousEmployer  \
# 0       43271911         False              False
# 1       55494312         False              False
# 2       29190623         False              False
# 3       19552101         False              False
# 4       64942212         False              False
# 5       25328949         False              False
# 6       18632276         False              False
# 7       16834017         False              False
# 8       64942212         False              False
# 9       27186386         False              False
# 10      62786515         False              False
# 11      10108330         False              False
# 12      34730466         False              False
# 13      12854358         False              False
# 14      10213231         False              False
# 15      29190623         False              False
# 16      10108330         False              False
# 17      10108330         False              False
# 18      10213231         False              False
# 19      11259979         False              False
#
#                                              ShareUrl  \
# 0   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 1   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 2   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 3   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 4   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 5   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 6   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 7   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 8   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 9   https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 10  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 11  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 12  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 13  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 14  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 15  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 16  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 17  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 18  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 19  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
#
#                                            DetailsUrl  \
# 0   https://job.jobnet.dk/CV/FindWork/Details/5390394
# 1   https://job.jobnet.dk/CV/FindWork/Details/5370739
# 2   https://job.jobnet.dk/CV/FindWork/Details/5399061
# 3   https://job.jobnet.dk/CV/FindWork/Details/5395379
# 4   https://job.jobnet.dk/CV/FindWork/Details/5393351
# 5   https://job.jobnet.dk/CV/FindWork/Details/5391812
# 6   https://job.jobnet.dk/CV/FindWork/Details/5386664
# 7   https://job.jobnet.dk/CV/FindWork/Details/5383001
# 8   https://job.jobnet.dk/CV/FindWork/Details/5400876
# 9   https://job.jobnet.dk/CV/FindWork/Details/5400349
# 10  https://job.jobnet.dk/CV/FindWork/Details/5400309
# 11  https://job.jobnet.dk/CV/FindWork/Details/5400213
# 12  https://job.jobnet.dk/CV/FindWork/Details/5400180
# 13  https://job.jobnet.dk/CV/FindWork/Details/5400175
# 14  https://job.jobnet.dk/CV/FindWork/Details/5400029
# 15  https://job.jobnet.dk/CV/FindWork/Details/5399545
# 16  https://job.jobnet.dk/CV/FindWork/Details/5398992
# 17  https://job.jobnet.dk/CV/FindWork/Details/5399154
# 18  https://job.jobnet.dk/CV/FindWork/Details/5399070
# 19  https://job.jobnet.dk/CV/FindWork/Details/5398309
#
#                                             JobLogUrl HasLocationValues  \
# 0   https://job.jobnet.dk/CV/FindWork/Details/5390394              True
# 1   https://job.jobnet.dk/CV/FindWork/Details/5370739              True
# 2   https://job.jobnet.dk/CV/FindWork/Details/5399061              True
# 3   https://job.jobnet.dk/CV/FindWork/Details/5395379              True
# 4   https://job.jobnet.dk/CV/FindWork/Details/5393351              True
# 5   https://job.jobnet.dk/CV/FindWork/Details/5391812              True
# 6   https://job.jobnet.dk/CV/FindWork/Details/5386664              True
# 7   https://job.jobnet.dk/CV/FindWork/Details/5383001              True
# 8   https://job.jobnet.dk/CV/FindWork/Details/5400876              True
# 9   https://job.jobnet.dk/CV/FindWork/Details/5400349              True
# 10  https://job.jobnet.dk/CV/FindWork/Details/5400309              True
# 11  https://job.jobnet.dk/CV/FindWork/Details/5400213              True
# 12  https://job.jobnet.dk/CV/FindWork/Details/5400180              True
# 13  https://job.jobnet.dk/CV/FindWork/Details/5400175              True
# 14  https://job.jobnet.dk/CV/FindWork/Details/5400029              True
# 15  https://job.jobnet.dk/CV/FindWork/Details/5399545              True
# 16  https://job.jobnet.dk/CV/FindWork/Details/5398992              True
# 17  https://job.jobnet.dk/CV/FindWork/Details/5399154              True
# 18  https://job.jobnet.dk/CV/FindWork/Details/5399070              True
# 19  https://job.jobnet.dk/CV/FindWork/Details/5398309              True
#
#          ID  Latitude  Longitude
# 0   5390394   55.6746    12.5891
# 1   5370739   55.6762    12.5804
# 2   5399061   55.7122    12.5418
# 3   5395379   55.6266    12.5769
# 4   5393351   55.6960    12.5253
# 5   5391812   55.6771    12.5649
# 6   5386664   55.6690    12.5680
# 7   5383001   55.6735    12.5753
# 8   5400876   55.6960    12.5253
# 9   5400349   55.6632    12.5587
# 10  5400309   55.6583    12.5903
# 11  5400213   55.6756    12.5818
# 12  5400180   55.6725    12.5850
# 13  5400175   55.6748    12.5847
# 14  5400029   55.6833    12.5859
# 15  5399545   55.7383    12.5453
# 16  5398992   55.6756    12.5818
# 17  5399154   55.6756    12.5818
# 18  5399070   55.6833    12.5859
# 19  5398309   55.6795    12.5156
#
# [20 rows x 46 columns]

# %%
assert sorted(df.columns) == ['Abroad', 'AnonymousEmployer', 'AssignmentStartDate', 'AutomatchType', 'Country', 
                              'DetailsUrl', 'EmploymentType', 'FormattedLastDateApplication', 'HasLocationValues', 
                              'HiringOrgCVR', 'HiringOrgName', 'ID', 'IsExternal', 'IsHotjob', 'JobAnnouncementType', 
                              'JobHeadline', 'JobLogUrl', 'JoblogWorkTime', 'LastDateApplication', 'Latitude', 'Location',
                              'Longitude', 'Municipality', 'Occupation', 'OccupationArea', 'OccupationGroup', 
                              'OrganisationId', 'PostalCode', 'PostalCodeName', 'PostingCreated', 'Presentation',
                              'Region', 'ShareUrl', 'Title', 'Url', 'UseWorkPlaceAddressForJoblog', 'UserLoggedIn',
                              'Weight', 'WorkHours', 'WorkPlaceAbroad', 'WorkPlaceAddress', 'WorkPlaceCity',
                              'WorkPlaceNotStatic', 'WorkPlaceOtherAddress', 'WorkPlacePostalCode', 'WorkplaceID']
assert len(df) == 20

# %% [markdown]
# > **Ex. 6.1.3.:** How many results do you find in total? Store this number as 'TotalResultCount' for later use.

# %%
len(df)

TotalResultCount = page.json()['TotalResultCount']
print(TotalResultCount)
# Out:
# 134

# %% [markdown]
# ## Problems from Exercise Set 7
#
# > **Ex. 7.2.1:** Here we practice locating the table node of interest using the `find` method build into BeautifoulSoup. But first we have to fetch the HTML using the `requests` module. Parse the tree using `BeautifulSoup`. Next, use the **>Inspector<** tool (*right click on the table < press inspect element*) in your browser to see how to locate the Eastern Conference table node - i.e. the *tag* name of the node, and maybe some defining *attributes*.

# %%
# Define url
url = 'https://www.basketball-reference.com/leagues/NBA_2018.html'

# connects to site
response = requests.get(url)

# parse data with BeautifulSoup
soup = BeautifulSoup(response.content,'html.parser') # parse the HTML
soup.find_all()

# len(soup.find_all('table'))

soup.find_all('table',{'id':'confs_standings_E'})

#identify articles to scrape by inspecting site
test = str(soup.find_all('table',{'id':'confs_standings_E'})[0]) # search for the ul node

df = pd.read_html(test)[0]
df
# checking if articles match website
# for i in range(1):
#     print(articles[i].text.strip())

# identifying how to find an url from an article
# article_url = articles[0].attrs['data-vr-contentbox-url']
# print(article_url)
# Out:
#       Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0       Toronto Raptors*  59  23  0.720     —  111.7  103.9  7.29
# 1        Boston Celtics*  55  27  0.671   4.0  104.0  100.4  3.23
# 2    Philadelphia 76ers*  52  30  0.634   7.0  109.8  105.3  4.30
# 3   Cleveland Cavaliers*  50  32  0.610   9.0  110.9  109.9  0.59
# 4        Indiana Pacers*  48  34  0.585  11.0  105.6  104.2  1.18
# 5            Miami Heat*  44  38  0.537  15.0  103.4  102.9  0.15
# 6       Milwaukee Bucks*  44  38  0.537  15.0  106.5  106.8 -0.45
# 7    Washington Wizards*  43  39  0.524  16.0  106.6  106.0  0.53
# 8        Detroit Pistons  39  43  0.476  20.0  103.8  103.9 -0.26
# 9      Charlotte Hornets  36  46  0.439  23.0  108.2  108.0  0.07
# 10       New York Knicks  29  53  0.354  30.0  104.5  108.0 -3.53
# 11         Brooklyn Nets  28  54  0.341  31.0  106.6  110.3 -3.67
# 12         Chicago Bulls  27  55  0.329  32.0  102.9  110.0 -6.84
# 13         Orlando Magic  25  57  0.305  34.0  103.4  108.2 -4.92
# 14         Atlanta Hawks  24  58  0.293  35.0  103.4  108.8 -5.30
